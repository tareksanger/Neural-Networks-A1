# %%
import matplotlib.pyplot as plt

from helpers.constants import TARGET_PATTERNS, DISTORTED_PATTERNS, VALIDATION_PATTERNS 
from helpers.constants import NOISE_LEVEL_1, NOISE_LEVEL_2, NOISE_LEVEL_3

# %%
# Display Target Sample
plt.figure()
count = 0
for l in TARGET_PATTERNS['x']:
    plt.subplot(5, 7, count + 1)
    plt.axis('off')
    plt.imshow(l)
    
    count +=1

# %%
# DISTORTED PATTERNS

plt.figure()
count = 0
for l in DISTORTED_PATTERNS['x']:
    plt.subplot(5, 7, count + 1)
    plt.axis('off')
    plt.imshow(l)
    
    count +=1

# %%
# VALIDATION_PATTERNS

plt.figure()
count = 0
for l in VALIDATION_PATTERNS['x']:
    plt.subplot(5, 7, count + 1)
    plt.axis('off')
    plt.imshow(l)
    
    count +=1

# %%
plt.figure()
count = 0
for l in NOISE_LEVEL_1['x']:
    plt.subplot(5, 7, count + 1)
    plt.axis('off')
    plt.imshow(l)
    
    count +=1

# %%
plt.figure()
count = 0
for l in NOISE_LEVEL_2['x']:
    plt.subplot(5, 7, count + 1)
    plt.axis('off')
    plt.imshow(l)
    
    count +=1

# %%
plt.figure()
count = 0
for l in NOISE_LEVEL_3['x']:
    plt.subplot(5, 7, count + 1)
    plt.axis('off')
    plt.imshow(l)
    
    count +=1
